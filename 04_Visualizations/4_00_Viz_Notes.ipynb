# %% [markdown]
# Make a plot of the correlation between valence and mode.
# Show why we don't need mode.
# Valence is more sophisticated indicator of happiness.

# %% [markdown]
# looks how audio features of each class compare (how average bounciness of one class compares to another).

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# We can see the the two different sentiment analyzers I've used do not correlate strongly with each other.
# Bearing that in mind I have decided to use both as I believe they are both capturing signal the the others were unable to capture.

# %%
plt.figure(figsize=(10,8))
corr_df = combined_sentiment.corr()
sns.heatmap(corr_df, annot=True,cmap='viridis');

# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_pickle('../Data/labeled_points_tf-idf_pca_12')
df.rename(columns={0: 'lyrics_feature_0',
                   1: 'lyrics_feature_1',
                   2: 'lyrics_feature_2'},
          inplace=True)

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

# %%
features = df.select_dtypes(include=numerics)
no_features = df.select_dtypes(exclude=numerics)

# %%
plt.figure(figsize=(12, 10))
corr_df = features.corr()
sns.heatmap(corr_df, annot=True, cmap='viridis');

# %%
df.labels.values.tostring
# Out:
# <function ndarray.tostring>

# %%
df = pd.read_pickle('../Data/cv_df_pca_features')
df.rename(columns={0: 'lyrics_feature_0',
                   1: 'lyrics_feature_1',
                   2: 'lyrics_feature_2'},
          inplace=True)

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

# %%
features = df.select_dtypes(include=numerics)
no_features = df.select_dtypes(exclude=numerics)

# %%
plt.figure(figsize=(12, 10))
corr_df = features.corr()
sns.heatmap(corr_df, annot=True, cmap='viridis');
